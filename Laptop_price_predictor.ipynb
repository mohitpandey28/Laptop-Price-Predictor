# %%
pip install --upgrade pandas

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/laptop.csv/laptop_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'],inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Ram']= df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
import seaborn as sns

# %%
sns.distplot(df['Price'])
# Out:
# <ipython-input-120-87e11caeb2c4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

sns.barplot(x= df['Company'],y=df['Price'])
plt.xticks(rotation ='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
 sns.barplot(x= df['TypeName'],y=df['Price'],palette='icefire')
plt.xticks(rotation ='vertical')
plt.show()
# Out:
# <ipython-input-124-2f6409be471b>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x= df['TypeName'],y=df['Price'],palette='icefire')

# %%
sns.distplot(df['Inches'])
# Out:
# <ipython-input-125-51888cb550e6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x : 1 if 'Touchscreen' in x else 0)

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches  \
# 59      Asus            Notebook    15.6
# 1302    Asus            Notebook    15.6
# 367   Lenovo              Gaming    15.6
# 443   Lenovo            Notebook    15.6
# 259   Lenovo  2 in 1 Convertible    15.6
#
#                                ScreenResolution  \
# 59                            Full HD 1920x1080
# 1302                                   1366x768
# 367                 IPS Panel Full HD 1920x1080
# 443                           Full HD 1920x1080
# 259   IPS Panel Full HD / Touchscreen 1920x1080
#
#                                        Cpu  Ram                Memory  \
# 59                Intel Core i3 6006U 2GHz    4             256GB SSD
# 1302  Intel Celeron Dual Core N3050 1.6GHz    4             500GB HDD
# 367            Intel Core i5 7300HQ 2.5GHz    8  128GB SSD +  1TB HDD
# 443   Intel Pentium Quad Core N4200 1.1GHz    4             128GB SSD
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
custom_palette = ['red', 'green']
sns.barplot(x=df['Touchscreen'],y=df['Price'],palette = custom_palette)
# Out:
# <ipython-input-130-9860fe187a79>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Touchscreen'],y=df['Price'],palette = custom_palette)
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df['IPS'] = df['ScreenResolution'].apply(lambda x : 1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df['IPS'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
custom_palette = ['red', 'green']
sns.barplot(x=df['IPS'],y=df['Price'],palette = custom_palette)
# Out:
# <ipython-input-134-2a912f87b215>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['IPS'],y=df['Price'],palette = custom_palette)
# <Axes: xlabel='IPS', ylabel='Price'>

# %%
new = df['ScreenResolution'].str.split('x',n=2,expand=True)

# %%
df['x_res'] = new[0]
df['y_res'] = new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['x_res'] = df['x_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x : x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
#      str.replace(',', ''): This is a string method that replaces any commas ',' with an empty string ''
#                     in each element of the 'x_res' column.
#      It's used to remove any commas that might be present in the resolution values.
#.     For example, if a resolution is '1,920', this operation would transform it to '1920'.


#      str.findall(r'(\d+\.?\d+)'): This is another string method that applies a regular expression pattern
#      r'(\d+\.?\d+)' to each element of the 'x_res' column after commas are removed. Let's break down the regular expression:
#.     \d+ : Matches one or more digits.
#.     \.? : Matches an optional decimal point.
#.     \d+ : Matches one or more digits after the decimal point (if present).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  x_res             1303 non-null   object
#  14  y_res             1303 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# ...

# %%
df['x_res'] = df['x_res'].astype('int')
df['y_res'] = df['y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  x_res             1303 non-null   int64
#  14  y_res             1303 non-null   int64
# dtypes: float32(1), float64(2), int32(1), int64(4), object(7)
# ...

# %%
df.corr()['Price']
# Out:
# <ipython-input-144-9447c1bc3d29>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# x_res          0.556529
# y_res          0.552809
# Name: Price, dtype: float64

# %%
df['PPI'] = (((df['x_res']**2) + (df['y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.corr()['Price']
# Out:
# <ipython-input-146-9447c1bc3d29>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# x_res          0.556529
# y_res          0.552809
# PPI            0.473487
# Name: Price, dtype: float64

# %%
df.drop(columns = ['ScreenResolution','x_res','y_res','Inches'],inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI
# 0  226.983005
# 1  127.677940
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       Cpu Name
# ...

# %%
def fetch_processor(text):
  if text == 'Intel Core i7' or text =='Intel Core i5' or text =='Intel Core i3':
   return text
  else:
    if text.split()[0] == 'Intel':
      return 'Other Intel Processor'
    else:
      return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       Cpu Name      Cpu brand
# ...

# %%
df['Cpu brand'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Cpu brand'], y=df['Price'],palette ='coolwarm')
plt.xticks(rotation = 'vertical')
plt.show()
# Out:
# <ipython-input-156-971ec1b72bbd>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Cpu brand'], y=df['Price'],palette ='coolwarm')

# %%
 df.drop(columns = ['Cpu','Cpu Name'],inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS         PPI      Cpu brand
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Ram'],y=df['Price'],palette = 'coolwarm')
plt.xticks(rotation = 'vertical')
plt.show()
# Out:
# <ipython-input-160-3e26c02812b8>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Ram'],y=df['Price'],palette = 'coolwarm')

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0','',regex = True)
df['Memory'] = df['Memory'].str.replace('GB','')
df['Memory'] = df['Memory'].str.replace('TB','000')

new = df['Memory'].str.split('+',n=1,expand=True)                          # 'n' mean split in how many times as "+" indicate delimiter here

df['first'] = new[0]
df['first'] = df['first'].str.strip()                                                    # 'strip' is used to remove unwanted space and gap

df['second'] = new[1]

df['Layer1HDD'] = df['first'].apply(lambda x : 1 if 'HDD' in x else 0)
df['Layer1SSD'] = df['first'].apply(lambda x : 1 if 'SSD' in x else 0)
df['Layer1Hybrid'] = df['first'].apply(lambda x : 1 if 'Hybrid' in x else 0)
df['Layer1Flash_Storage'] = df['first'].apply(lambda x : 1 if 'Flash Storage' in x else 0)

df['first'] = df['first'].str.replace(r'\D','')                          #  \D: This is a regular expression pattern that matches
                                                                           #  any character that is not a digit (0-9)

df['second'].fillna('0',inplace = True)

df['Layer2HDD'] = df['second'].apply(lambda x : 1 if 'HDD' in x else 0)
df['Layer2SSD'] = df['second'].apply(lambda x : 1 if 'SSD' in x else 0)
df['Layer2Hybrid'] = df['second'].apply(lambda x : 1 if 'Hybrid' in x else 0)
df['Layer2Flash_Storage'] = df['second'].apply(lambda x : 1 if 'Flash Storage' in x else 0)


df['second'] = df['second'].str.replace(r'\D','')

df['first'] = df['first'].astype(int)
df['second'] = df['second'].astype(int)


df['first'] = df['first'].astype(int)
df['second'] = df['second'].astype(int)

df['HDD'] = df['first']* df['Layer1HDD'] + df['second']*df['Layer2HDD']
df['SSD'] = df['first']* df['Layer1SSD'] + df['second']*df['Layer2SSD']
df['Hybrid'] = df['first']* df['Layer1Hybrid'] + df['second']*df['Layer2Hybrid']
df['Flash_Storage'] = df['first']* df['Layer1Flash_Storage'] + df['second']*df['Layer2Flash_Storage']

df.drop(columns = ['first','second','Layer1HDD','Layer1SSD','Layer1Hybrid','Layer1Flash_Storage',
                   'Layer2HDD','Layer2SSD','Layer2Hybrid','Layer2Flash_Storage'],inplace = True)
# Out:
# <ipython-input-161-4bb8f1d3cd0c>:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D','')                          #  \D: This is a regular expression pattern that matches
# <ipython-input-161-4bb8f1d3cd0c>:28: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D','')

# %%
df.sample(5)
# Out:
#      Company            TypeName  Ram               Memory  \
# 295   Lenovo              Gaming    8             1000 HDD
# 1230  Lenovo             Netbook   16              512 SSD
# 1061    Asus              Gaming   16             1000 HDD
# 165      MSI              Gaming   16  256 SSD +  1000 HDD
# 234     Acer  2 in 1 Convertible    8              256 SSD
#
#                           Gpu       OpSys  Weight     Price  Touchscreen  IPS  \
# 295   Nvidia GeForce GTX 1060  Windows 10     3.2  69210.72            0    1
# 1230    Intel HD Graphics 520  Windows 10     1.3  87912.00            1    1
# 1061  Nvidia GeForce GTX 965M       No OS     4.0  53173.44            0    1
# 165   Nvidia GeForce GTX 1060  Windows 10     2.4  95850.72            0    1
# 234     Intel HD Graphics 520  Windows 10     1.6  36709.92            1    1
#
#              PPI      Cpu brand   HDD  SSD  Hybrid  Flash_Storage
# 295   141.211998  Intel Core i7  1000    0       0              0
# ...

# %%
df.drop(columns = ['Memory'],inplace = True)

# %%
df.sample(5)
# Out:
#      Company  TypeName  Ram                         Gpu       OpSys  Weight  \
# 679     Acer    Gaming   16  Nvidia GeForce GTX 1050 Ti  Windows 10    2.50
# 340     Dell  Notebook    4           Intel HD Graphics       Linux    2.20
# 834   Lenovo  Notebook    8       Intel HD Graphics 620  Windows 10    1.32
# 850       HP  Notebook    4       Intel HD Graphics 400       No OS    1.86
# 1078  Lenovo  Notebook    4       Intel HD Graphics 520  Windows 10    2.10
#
#           Price  Touchscreen  IPS         PPI              Cpu brand  HDD  \
# 679   69210.720            0    0  141.211998          Intel Core i5    0
# 340   14646.672            0    0  100.454670  Other Intel Processor  500
# 834   87912.000            0    1  157.350512          Intel Core i5    0
# 850   15930.720            0    0  100.454670  Other Intel Processor    0
# 1078  28771.200            0    0  100.454670          Intel Core i5  500
#
#       SSD  Hybrid  Flash_Storage
# ...

# %%
df.corr()['Price']
# Out:
# <ipython-input-165-9447c1bc3d29>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# IPS              0.252208
# PPI              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns = ['Hybrid','Flash_Storage'],inplace = True)

# %%
df.sample(5)
# Out:
#      Company            TypeName  Ram                      Gpu       OpSys  \
# 677       HP  2 in 1 Convertible    8    Intel HD Graphics 500   Chrome OS
# 887     Asus              Gaming   12  Nvidia GeForce GTX 1050  Windows 10
# 501       HP            Notebook    8           AMD Radeon 520  Windows 10
# 1279  Lenovo            Notebook    8  Nvidia GeForce GTX 960M  Windows 10
# 396   Lenovo            Notebook    8        AMD Radeon RX 550  Windows 10
#
#       Weight       Price  Touchscreen  IPS         PPI              Cpu brand  \
# 677     1.40  26373.6000            1    0  135.094211  Other Intel Processor
# 887     2.20  72988.2720            0    0  127.335675          Intel Core i5
# 501     1.91  32979.7872            0    0  100.454670          Intel Core i5
# 1279    2.60  47898.7200            0    1  141.211998          Intel Core i7
# 396     2.10  65510.9568            0    1  141.211998          Intel Core i7
#
#        HDD  SSD
# 677      0    0
# ...

# %%
df['Gpu Brand'] = df['Gpu'].apply(lambda x: x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         PPI      Cpu brand  HDD  SSD  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256
#
#   Gpu Brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df['Gpu Brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu Brand, dtype: int64

# %%
df = df[df['Gpu Brand'] != 'ARM']

# %%
df['Gpu Brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu Brand, dtype: int64

# %%
sns.barplot(x= df['Gpu Brand'],y=df['Price'],palette='coolwarm',estimator = np.median)
plt.xticks(rotation = 'vertical')
plt.show()
# Out:
# <ipython-input-173-060a760d81ca>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x= df['Gpu Brand'],y=df['Price'],palette='coolwarm',estimator = np.median)

# %%
df.drop(columns = ['Gpu'],inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI      Cpu brand  HDD  SSD Gpu Brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x= df['OpSys'],y=df['Price'],palette='coolwarm')
plt.xticks(rotation = 'vertical')
plt.show()
# Out:
# <ipython-input-177-b0add8915ba4>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x= df['OpSys'],y=df['Price'],palette='coolwarm')

# %%
def cat_os(inp):
  if inp =='Windows 10' or inp =='Windows 10 S' or inp =='Windows 7':
    return 'Windows'
  elif inp == 'macOS' or inp == 'Mac OS X':
    return 'Mac'
  else:
    return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)

# %%
df.sample(5)
# Out:
#      Company   TypeName  Ram       OpSys  Weight     Price  Touchscreen  IPS  \
# 938     Dell  Ultrabook    8  Windows 10    1.36  87325.92            0    0
# 719       HP   Notebook    8  Windows 10    2.63  63936.00            0    0
# 1290    Dell   Notebook    6  Windows 10    2.30  24455.52            0    0
# 810       HP     Gaming   12  Windows 10    3.74  93186.72            0    1
# 184   Xiaomi   Notebook    8       No OS    1.95  63882.72            0    1
#
#              PPI      Cpu brand   HDD  SSD Gpu Brand                  os
# 938   157.350512  Intel Core i5     0  256     Intel             Windows
# 719   127.335675  Intel Core i7     0  256    Nvidia             Windows
# 1290  100.454670  Intel Core i3  1000    0     Intel             Windows
# 810   127.335675  Intel Core i7  1000    0       AMD             Windows
# 184   141.211998  Intel Core i5     0  256    Nvidia  Others/No OS/Linux

# %%
sns.barplot(x= df['os'],y=df['Price'],palette='coolwarm')
plt.xticks(rotation = 'vertical')
plt.show()
# Out:
# <ipython-input-181-7a6851209817>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x= df['os'],y=df['Price'],palette='coolwarm')

# %%
df.drop(columns = ['OpSys'],inplace = True)

# %%
df.sample(5)
# Out:
#     Company  TypeName  Ram  Weight      Price  Touchscreen  IPS         PPI  \
# 836    Asus    Gaming   16    2.90  128884.32            0    0  127.335675
# 609    Acer  Notebook    4    1.60   18594.72            0    0  111.935204
# 520  Lenovo    Gaming    8    3.20   74538.72            0    1  141.211998
# 568  Lenovo  Notebook    4    2.20   18328.32            0    0  141.211998
# 584    Dell   Netbook    4    1.26   15717.60            0    0  135.094211
#
#                  Cpu brand   HDD  SSD Gpu Brand                  os
# 836          Intel Core i7  1000  256    Nvidia             Windows
# 609  Other Intel Processor     0    0     Intel             Windows
# 520          Intel Core i7  1000  256    Nvidia             Windows
# 568  Other Intel Processor   500    0     Intel             Windows
# 584  Other Intel Processor     0    0     Intel  Others/No OS/Linux

# %%
sns.distplot(df['Weight'])
# Out:
# <ipython-input-184-05ee4c8848be>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x = df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df.corr()['Price']
# Out:
# <ipython-input-186-9447c1bc3d29>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# IPS            0.253320
# PPI            0.475368
# HDD           -0.096891
# SSD            0.670660
# Name: Price, dtype: float64

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-187-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
x= df.drop(columns =['Price'])
y =np.log(df['Price'])

# %%
x
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPS         PPI  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
# !pip install --upgrade scikit-learn

# %%
# !pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.15,random_state = 2)

# %%
x_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  IPS         PPI  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193    Apple           Ultrabook    8    0.92            0    1  226.415547
#
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ##**Linear Regression**

# %%
step1 = ColumnTransformer(transformers = [
    ('col_tnf',OneHotEncoder(drop ='first'),[0,1,7,10,11])],
    remainder = 'passthrough')

step2 = LinearRegression()

pipe =Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 score',r2_score(y_pred,y_test))
print('MAE',mean_absolute_error(y_pred,y_test))
# Out:
# R2 score 0.7677401695079884
# MAE 0.2101782797642888

# %% [markdown]
# ##**KNN**

# %%
step1 = ColumnTransformer(transformers = [
    ('col_tnf',OneHotEncoder(drop ='first'),[0,1,7,10,11])],
    remainder = 'passthrough')

step2 = KNeighborsRegressor(n_neighbors = 3)

pipe =Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 score',r2_score(y_pred,y_test))
print('MAE',mean_absolute_error(y_pred,y_test))
# Out:
# R2 score 0.7978853259313476
# MAE 0.19346118183798544

# %% [markdown]
# ##**DecisionTree**

# %%
step1 = ColumnTransformer(transformers = [
    ('col_tnf',OneHotEncoder(drop ='first'),[0,1,7,10,11])],
    remainder = 'passthrough')

step2 = DecisionTreeRegressor(max_depth = 8)

pipe =Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 score',r2_score(y_pred,y_test))
print('MAE',mean_absolute_error(y_pred,y_test))
# Out:
# R2 score 0.8229906748563354
# MAE 0.18434488162781357

# %% [markdown]
# ##**SVM**

# %%
step1 = ColumnTransformer(transformers = [
    ('col_tnf',OneHotEncoder(drop ='first'),[0,1,7,10,11])],
    remainder = 'passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe =Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 score',r2_score(y_pred,y_test))
print('MAE',mean_absolute_error(y_pred,y_test))


 # kernel = rbf--> mean suitable for non-linear
 #               regression tasks and is flexible in capturing complex relationships between features and the target variable.

 # The parameter C---> is the regularization parameter, which controls the trade-off between maximizing the margin and minimizing the training error.
 #                     A larger C value means less regularization, allowing the model to fit the training data more closely,
 #                     potentially leading to overfitting

 # epsilon --->      is a hyperparameter that controls the width of the margin of tolerance around the predicted values
# Out:
# R2 score 0.7877799579841563
# MAE 0.20239059427315706

# %% [markdown]
# ##**RandomForest**

# %%
step1 = ColumnTransformer(transformers = [
    ('col_tnf',OneHotEncoder(drop ='first'),[0,1,7,10,11])],
    remainder = 'passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe =Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 score',r2_score(y_pred,y_test))
print('MAE',mean_absolute_error(y_pred,y_test))
# Out:
# R2 score 0.8695033719418028
# MAE 0.15860130110457718

# %%
import pickle

# %%
pickle.dump(df,open('df1.pkl','wb'))
pickle.dump(pipe,open('pipe1.pkl','wb'))
